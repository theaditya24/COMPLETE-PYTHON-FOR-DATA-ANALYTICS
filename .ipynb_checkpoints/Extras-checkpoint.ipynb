# %%
type(print)
# Out:
# builtin_function_or_method

# %%
type("Data Analyst 123")
# Out:
# str

# %%
my_own_print_func = print
my_own_print_func("hello")
# Out:
# hello

# %%
print # this will gonna tell us what is print is basically
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print('helllo! there') # this will gonna run or print anything that we will gonna put inside this func as arguments
# Out:
# helllo! there
