# %% [markdown]
# # United States - Crime Rates - 1960 - 2014

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called crime.

# %%
crime = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv')

# %%
crime.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %% [markdown]
# ### Step 4. What is the type of the columns?

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %% [markdown]
# ##### Have you noticed that the type of Year is int64. But pandas has a different type to work with Time Series. Let's see it now.
#
# ### Step 5. Convert the type of the column Year to datetime64

# %%
crime['Year'] = pd.to_datetime(crime['Year'], format='%Y', errors='coerce')
crime.head()
# Out:
#         Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 2 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 3 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 4 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %% [markdown]
# ### Step 6. Set the Year column as the index of the dataframe

# %%
# crime.index = crime['Year']
# crime = crime.drop('Year', axis=1)
# crime.head()

# or this one
crime = crime.set_index('Year')
crime.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %% [markdown]
# ### Step 7. Delete the Total column

# %%
crime = crime.drop(columns = 'Total')
crime.head()
# Out:
#             Population  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960-01-01   179323175   288460   3095700    9110          17190   107840
# 1961-01-01   182992000   289390   3198600    8740          17220   106670
# 1962-01-01   185771000   301510   3450700    8530          17550   110860
# 1963-01-01   188483000   316970   3792500    8640          17650   116470
# 1964-01-01   191141000   364220   4200400    9360          21420   130390
#
#             Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1960-01-01              154320    912100        1855400         328200
# 1961-01-01              156760    949600        1913000         336000
# 1962-01-01              164570    994300        2089600         366800
# 1963-01-01              174210   1086400        2297800         408300
# 1964-01-01              203050   1213200        2514400         472800

# %% [markdown]
# ### Step 8. Group the year by decades and sum the values
#
# #### Pay attention to the Population column number, summing this column is a mistake

# %%
crime_by_decade = crime.resample('10YS').sum()

crime_by_decade['Population'] = crime.resample('10YS')['Population'].max()

crime_by_decade
# Out:
#             Population   Violent   Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960-01-01   201385000   4134930   45160900  106180         236720  1633510
# 1970-01-01   220099000   9607930   91383800  192230         554570  4159020
# 1980-01-01   248239000  14074328  117048900  206439         865639  5383109
# 1990-01-01   272690813  17527048  119053499  211664         998827  5748930
# 2000-01-01   307006550  13968056  100944369  163068         922499  4230366
# 2010-01-01   318857056   6072017   44095950   72867         421059  1749809
#
#             Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1960-01-01             2158520  13321100       26547700        5292100
# 1970-01-01             4702120  28486000       53157800        9739900
# 1980-01-01             7619130  33073494       72040253       11935411
# 1990-01-01            10568963  26750015       77679366       14624418
# ...

# %%
crime_by_decade = crime.resample('10YS')
crime_by_decade

# %% [markdown]
# ### Pandas: `groupby()` vs `resample()`
#
# #### `groupby()`
#
# #### Definition
# Groups data based on the values of one or more columns.
#
# #### Syntax
#
# ```python
# df.groupby('column_name').agg_function()
# ```
#
# #### Example
#
# ```python
# df.groupby('Department')['Salary'].mean()
# ```
#
# #### Use Cases
# - Category-wise analysis
# - Department-wise salary
# - Gender-wise count
# - Product-wise sales
# - Customer-wise revenue
#
# #### Works On
# - Any column
# - Numeric or categorical data
#
# #### Common Aggregations
#
# ```python
# .sum()
# .mean()
# .max()
# .min()
# .count()
# .size()
# .nunique()
# ```
#
# ---
#
# ### `resample()`
#
# #### Definition
# Groups data based on time intervals.
#
# #### Syntax
#
# ```python
# df.resample('frequency').agg_function()
# ```
#
# #### Example
#
# ```python
# df.resample('M').sum()
# ```
#
# #### Use Cases
# - Monthly sales
# - Quarterly revenue
# - Yearly profit
# - Weekly orders
# - Decade-wise crime statistics
#
# #### Requirements
#
# - DataFrame index must be:
#   - DatetimeIndex
#   - TimedeltaIndex
#   - PeriodIndex
#
# Example:
#
# ```python
# df['Date'] = pd.to_datetime(df['Date'])
# df = df.set_index('Date')
# ```
#
# ---
#
# ### Common Resample Frequencies
#
# | Frequency | Meaning |
# |-----------|---------|
# | `'D'` | Daily |
# | `'W'` | Weekly |
# | `'ME'` | Month End |
# | `'MS'` | Month Start |
# | `'QE'` | Quarter End |
# | `'QS'` | Quarter Start |
# | `'YE'` | Year End |
# | `'YS'` | Year Start |
# | `'10YS'` | Every 10 Years |
#
# Example:
#
# ```python
# df.resample('ME').sum()
# df.resample('YE').mean()
# df.resample('10YS').max()
# ```
#
# ---
#
# ### Difference Between `groupby()` and `resample()`
#
# | Feature | `groupby()` | `resample()` |
# |----------|-------------|--------------|
# | Groups By | Column values | Time intervals |
# | Works On | Any DataFrame | Time-indexed DataFrame |
# | Requires Datetime Index | ❌ No | ✅ Yes |
# | Used For | Categorical grouping | Time-series analysis |
# | Example | Department-wise salary | Monthly sales |
#
# ---
#
# ### Example
#
# #### Using `groupby()`
#
# ```python
# df.groupby('Gender')['Salary'].mean()
# ```
#
# Output
#
# ```
# Male      65000
# Female    60000
# ```
#
# ---
#
# #### Using `resample()`
#
# ```python
# df.resample('ME')['Sales'].sum()
# ```
#
# Output
#
# ```
# Jan    12000
# Feb    14500
# Mar    13200
# ```
#
# ---
#
# ### Interview One-Liner
#
# - **`groupby()` → Groups by column values.**
# - **`resample()` → Groups by time intervals (dates).**
#
# > Think of `resample()` as **time-based `groupby()`**.

# %% [markdown]
# ### Step 9. What is the most dangerous decade to live in the US?

# %%
crime_by_decade
# Out:
#             Population   Violent   Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960-01-01   201385000   4134930   45160900  106180         236720  1633510
# 1970-01-01   220099000   9607930   91383800  192230         554570  4159020
# 1980-01-01   248239000  14074328  117048900  206439         865639  5383109
# 1990-01-01   272690813  17527048  119053499  211664         998827  5748930
# 2000-01-01   307006550  13968056  100944369  163068         922499  4230366
# 2010-01-01   318857056   6072017   44095950   72867         421059  1749809
#
#             Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1960-01-01             2158520  13321100       26547700        5292100
# 1970-01-01             4702120  28486000       53157800        9739900
# 1980-01-01             7619130  33073494       72040253       11935411
# 1990-01-01            10568963  26750015       77679366       14624418
# ...

# %%
crime_by_decade['Violent_rate'] = (
    crime_by_decade['Violent'] / crime_by_decade['Population']
) * 100000

crime_by_decade['Violent_rate'].idxmax()
# Out:
# Timestamp('1990-01-01 00:00:00')

# %%
crime_by_decade['Total_Crime'] = (
    crime_by_decade['Violent'] +
    crime_by_decade['Property'] +
    crime_by_decade['Murder'] +
    crime_by_decade['Forcible_Rape'] +
    crime_by_decade['Robbery'] +
    crime_by_decade['Aggravated_assault'] +
    crime_by_decade['Burglary'] +
    crime_by_decade['Larceny_Theft'] +
    crime_by_decade['Vehicle_Theft']
)

crime_by_decade['Total_Crime'].idxmax()
# Out:
# Timestamp('1990-01-01 00:00:00')
