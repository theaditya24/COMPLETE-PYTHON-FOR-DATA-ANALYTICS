# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
data = {
    "employee_id": [101,102,103,104,105,106,107,108,109,110],
    
    "employee_name": [
        "Ravi","Aman","Sneha","Karan","Neha","Pooja","Rahul","Simran","Vikas","Anjali"],
    
    "department": ["IT","HR","IT","Sales","HR","Sales","IT","HR","Sales","IT"
    ],
    
    "city": [
        "Delhi","Mumbai","Delhi","Pune","Mumbai",
        "Delhi","Pune","Delhi","Mumbai","Pune"
    ],
    
    "gender": [
        "Male","Male","Female","Male","Female",
        "Female","Male","Female","Male","Female"
    ],
    
    "salary": [
        75000,50000,68000,45000,52000,
        47000,72000,51000,46000,80000
    ],
    
    "experience": [
        5,2,4,1,3,
        2,6,4,2,7
    ],
    
    "performance_score": [
        88,76,91,70,82,
        75,95,89,72,97
    ]
}

df = pd.DataFrame(data)
df
# Out:
#    employee_id employee_name department    city  gender  salary  experience  \
# 0          101          Ravi         IT   Delhi    Male   75000           5
# 1          102          Aman         HR  Mumbai    Male   50000           2
# 2          103         Sneha         IT   Delhi  Female   68000           4
# 3          104         Karan      Sales    Pune    Male   45000           1
# 4          105          Neha         HR  Mumbai  Female   52000           3
# 5          106         Pooja      Sales   Delhi  Female   47000           2
# 6          107         Rahul         IT    Pune    Male   72000           6
# 7          108        Simran         HR   Delhi  Female   51000           4
# 8          109         Vikas      Sales  Mumbai    Male   46000           2
# 9          110        Anjali         IT    Pune  Female   80000           7
#
#    performance_score
# 0                 88
# 1                 76
# 2                 91
# 3                 70
# ...

# %% [markdown]
# ### Retrieve the details of those employee whose experience is 2,4,5 and 7

# %%
df['experience'] in [2,4,5,7]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/gv/p6wrt2v92xq4_bvjnsdvfcwh0000gn/T/ipykernel_59495/2470616005.py in ?()
# ----> 1 df['experience'] in [2,4,5,7]
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df['experience'].isin([2,4,5,7])
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# 8     True
# 9     True
# Name: experience, dtype: bool

# %%
df[ df['experience'].isin([2,4,5,7])]
# Out:
#    employee_id employee_name department    city  gender  salary  experience  \
# 0          101          Ravi         IT   Delhi    Male   75000           5
# 1          102          Aman         HR  Mumbai    Male   50000           2
# 2          103         Sneha         IT   Delhi  Female   68000           4
# 5          106         Pooja      Sales   Delhi  Female   47000           2
# 7          108        Simran         HR   Delhi  Female   51000           4
# 8          109         Vikas      Sales  Mumbai    Male   46000           2
# 9          110        Anjali         IT    Pune  Female   80000           7
#
#    performance_score
# 0                 88
# 1                 76
# 2                 91
# 5                 75
# 7                 89
# 8                 72
# 9                 97

# %%
df.query('experience in (2,4,5,7)')
# Out:
#    employee_id employee_name department    city  gender  salary  experience  \
# 0          101          Ravi         IT   Delhi    Male   75000           5
# 1          102          Aman         HR  Mumbai    Male   50000           2
# 2          103         Sneha         IT   Delhi  Female   68000           4
# 5          106         Pooja      Sales   Delhi  Female   47000           2
# 7          108        Simran         HR   Delhi  Female   51000           4
# 8          109         Vikas      Sales  Mumbai    Male   46000           2
# 9          110        Anjali         IT    Pune  Female   80000           7
#
#    performance_score
# 0                 88
# 1                 76
# 2                 91
# 5                 75
# 7                 89
# 8                 72
# 9                 97

# %%
# select * from df where experience in (2,4,5,7)

# %% [markdown]
# ### Retrieve the details of those employee whose experience is 2,4,5,6,8,10,11 and 12

# %%
df = pd.DataFrame({
    'Region': ['North', 'South', 'East', 'West'],
    'Electronics': [120, 100, 140, 110],
    'Clothing': [80, 90, 60, 100],
    'Grocery': [60, 70, 90, 50]
})

# %%
df
# Out:
#   Region  Electronics  Clothing  Grocery
# 0  North          120        80       60
# 1  South          100        90       70
# 2   East          140        60       90
# 3   West          110       100       50

# %%
plt.bar( df['Region'], df['Electronics'] ,label="Electronics")
plt.bar( df['Region'], df['Clothing'], bottom=  df['Electronics'],label="Clothing")
plt.xlabel(" Region")
plt.ylabel(" Sales in Million $")
plt.legend()
plt.show()

# %%
plt.bar( df['Region'], df['Electronics'] ,label="Electronics")
plt.bar( df['Region'], df['Clothing'], bottom=  df['Electronics'],label="Clothing")
plt.bar( df['Region'], df['Grocery'], bottom=  df['Clothing'],label="Grocery")
plt.xlabel(" Region")
plt.ylabel(" Sales in Million $")
plt.legend()
plt.show()

# %%
plt.bar( df['Region'], df['Electronics'] ,label="Electronics")
plt.bar( df['Region'], df['Clothing'], bottom=  df['Electronics'],label="Clothing")
plt.bar( df['Region'], df['Grocery'], bottom= df['Electronics'] + df['Clothing'],label="Grocery")
plt.xlabel(" Region")
plt.ylabel(" Sales in Million $")
plt.legend()
plt.show()
