# %% [markdown]
# <!-- waq to print details of those students whose semester 2 marks
# is less than 80
# Select * FROM Students WHERE SEM2 < 80;
#
# waq to list details of those students whose total marks is
# greater than or equal to 175 where total marks is sum of sem1 and sem2
# SELECT * FROM Students WHERE (SEM1 + SEM2) >= 175;
#
# print details of those students whose avg marks is greater than or
# equal to 86
# SELECT * FROM Students WHERE (SEM1 + SEM2) >= 172;
#
# print details of those students whose sem1 and sem2 marks are
# are greater than 80
# SELECT * FROM Students WHERE (sem1 AND sem2) > 80;
#
# print detail of those marks whose any semester marks are greater
# than 80
# SELECT * FROM Students WHERE Sem1 > 80 OR sem2 > 80;
#
# print details of those students whose id is one and three
# SELECT * FROM Students WHERE Id = 3 OR Id = 1;
#
# print details of those students whose id is 1,2 and 4
# SELECT * FROM Students WHERE Id >= 1 AND Id <= 6 ;
#
# # waq to print details of those student whose second chracter is a and second last character is a
# SELECT *
# FROM Students
# WHERE Name LIKE '_a%' and Name LIKE '%a_';
# -->
