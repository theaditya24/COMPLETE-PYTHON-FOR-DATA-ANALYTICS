# %%
pip install tmdbsimple
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tmdbsimple as tmdb
tmdb.API_KEY = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlNTYxMzdjZmE5YmNhMjQzNTAzYmQ4MDQ4NzhhOGU4NiIsIm5iZiI6MTc4NzA2NDYzNS4zNDgsInN1YiI6IjZhODQ3MTNiNmUwYjI5OGZjMDU5NWQ4NyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.qqY8hbOuCJtONtfCXNCs1FGLXP9EWpcUk6IVrqapfmY'

# %%
import requests
tmdb.REQUESTS_SESSION = requests.Session()

# %%
tmdb.USE_BEARER_AUTH = True

# %%
movie = tmdb.Movies(603)
response = movie.info()

# %%
print(movie.title)
print(movie.release_date)
print(movie.vote_average)
# Out:
# The Matrix
# 1999-03-31
# 8.256

# %%
print(response)
# Out:
# {'adult': False, 'backdrop_path': '/tlm8UkiQsitc8rSuIAscQDCnP8d.jpg', 'belongs_to_collection': {'id': 2344, 'name': 'The Matrix Collection', 'poster_path': '/bV9qTVHTVf0gkW0j7p7M0ILD4pG.jpg', 'backdrop_path': '/bRm2DEgUiYciDw3myHuYFInD7la.jpg'}, 'budget': 63000000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 878, 'name': 'Science Fiction'}], 'homepage': 'http://www.warnerbros.com/matrix', 'id': 603, 'imdb_id': 'tt0133093', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'The Matrix', 'overview': 'Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth.', 'popularity': 42.1455, 'poster_path': '/dXNAPwY7VrqMAo51EKhhCJfaGb5.jpg', 'production_companies': [{'id': 79, 'logo_path': '/at4uYdwAAgNRKhZuuFX8ShKSybw.png', 'name': 'Village Roadshow Pictures', 'origin_country': 'US'}, {'id': 372, 'logo_path': None, 'name': 'Groucho II Film Partners
# ...

# %%
response.keys()
# Out:
# dict_keys(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id', 'imdb_id', 'origin_country', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'softcore', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count'])

# %%
import pandas as pd

df = pd.DataFrame([response])

df
# Out:
#    adult                     backdrop_path  \
# 0  False  /tlm8UkiQsitc8rSuIAscQDCnP8d.jpg
#
#                                belongs_to_collection    budget  \
# 0  {'id': 2344, 'name': 'The Matrix Collection', ...  63000000
#
#                                               genres  \
# 0  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
#
#                            homepage   id    imdb_id origin_country  \
# 0  http://www.warnerbros.com/matrix  603  tt0133093           [US]
#
#   original_language  ...    revenue runtime  softcore  \
# 0                en  ...  463517383     136     False
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                      tagline       title  video  vote_average  vote_count
# 0  Believe the unbelievable.  The Matrix  False         8.256       28551
#
# [1 rows x 27 columns]

# %%
df['belongs_to_collection'][0].keys()
# Out:
# dict_keys(['id', 'name', 'poster_path', 'backdrop_path'])

# %%
df.shape
# Out:
# (1, 27)

# %%
df.columns
# Out:
# Index(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres',
#        'homepage', 'id', 'imdb_id', 'origin_country', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'softcore', 'spoken_languages', 'status',
#        'tagline', 'title', 'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
df.dtypes
# Out:
# adult                       bool
# backdrop_path             object
# belongs_to_collection     object
# budget                     int64
# genres                    object
# homepage                  object
# id                         int64
# imdb_id                   object
# origin_country            object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                    int64
# runtime                    int64
# softcore                    bool
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                       bool
# vote_average             float64
# vote_count                 int64
# dtype: object

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['backdrop_path', 'belongs_to_collection', 'genres', 'homepage',
#        'imdb_id', 'origin_country', 'original_language', 'original_title',
#        'overview', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'spoken_languages', 'status',
#        'tagline', 'title'],
#       dtype='object')

# %%
for col in df.columns:
    value = df[col].iloc[0]
    
    if isinstance(value, (dict, list)):
        print(col, type(value))
# Out:
# belongs_to_collection <class 'dict'>
# genres <class 'list'>
# origin_country <class 'list'>
# production_companies <class 'list'>
# production_countries <class 'list'>
# spoken_languages <class 'list'>

# %%
for col in ['belongs_to_collection', 'genres', 'origin_country',
            'production_companies', 'production_countries', 'spoken_languages']:
    print(f"\n{col}:")
    print(df[col].iloc[0])
# Out:
# belongs_to_collection:
# {'id': 2344, 'name': 'The Matrix Collection', 'poster_path': '/bV9qTVHTVf0gkW0j7p7M0ILD4pG.jpg', 'backdrop_path': '/bRm2DEgUiYciDw3myHuYFInD7la.jpg'}
#
# genres:
# [{'id': 28, 'name': 'Action'}, {'id': 878, 'name': 'Science Fiction'}]
#
# origin_country:
# ['US']
#
# production_companies:
# [{'id': 79, 'logo_path': '/at4uYdwAAgNRKhZuuFX8ShKSybw.png', 'name': 'Village Roadshow Pictures', 'origin_country': 'US'}, {'id': 372, 'logo_path': None, 'name': 'Groucho II Film Partnership', 'origin_country': ''}, {'id': 1885, 'logo_path': '/xlvoOZr4s1PygosrwZyolIFe5xs.png', 'name': 'Silver Pictures', 'origin_country': 'US'}, {'id': 174, 'logo_path': '/zhD3hhtKB5qyv7ZeL4uLpNxgMVU.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}]
#
# production_countries:
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]
#
# spoken_languages:
# [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]

# %%
collection = pd.json_normalize(df['belongs_to_collection'])
df = pd.concat([df.drop(columns='belongs_to_collection'), collection], axis=1)

# %%
df.columns
# Out:
# Index(['adult', 'backdrop_path', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'origin_country', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'softcore', 'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'id', 'name', 'poster_path',
#        'backdrop_path'],
#       dtype='object')

# %%
# genres
df['genres'] = df['genres'].apply(
    lambda x: ', '.join([i['name'] for i in x]) if isinstance(x, list) else None
)

# origin_country
df['origin_country'] = df['origin_country'].apply(
    lambda x: ', '.join(x) if isinstance(x, list) else None
)

# production_companies
df['production_companies'] = df['production_companies'].apply(
    lambda x: ', '.join([i['name'] for i in x]) if isinstance(x, list) else None
)

# production_countries
df['production_countries'] = df['production_countries'].apply(
    lambda x: ', '.join([i['name'] for i in x]) if isinstance(x, list) else None
)

# spoken_languages
df['spoken_languages'] = df['spoken_languages'].apply(
    lambda x: ', '.join([i['english_name'] for i in x]) if isinstance(x, list) else None
)

# %%
for col in df.columns:
    value = df[col].iloc[0]
    
    if isinstance(value, (dict, list)):
        print(col, type(value))
# Out:
# belongs_to_collection <class 'dict'>

# %%
df.head()
# Out:
#    adult                     backdrop_path    budget                   genres  \
# 0  False  /tlm8UkiQsitc8rSuIAscQDCnP8d.jpg  63000000  Action, Science Fiction
#
#                            homepage   id    imdb_id origin_country  \
# 0  http://www.warnerbros.com/matrix  603  tt0133093             US
#
#   original_language original_title  ...    status                    tagline  \
# 0                en     The Matrix  ...  Released  Believe the unbelievable.
#
#         title  video vote_average vote_count    id                   name  \
# 0  The Matrix  False        8.255      28505  2344  The Matrix Collection
#
#                         poster_path                     backdrop_path
# 0  /bV9qTVHTVf0gkW0j7p7M0ILD4pG.jpg  /bRm2DEgUiYciDw3myHuYFInD7la.jpg
#
# [1 rows x 30 columns]

# %% [markdown]
# ## Want to get data of multiple movies

# %% [markdown]
# ### Getting multiple movie IDs

# %%
import tmdbsimple as tmdb

tmdb.API_KEY = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlNTYxMzdjZmE5YmNhMjQzNTAzYmQ4MDQ4NzhhOGU4NiIsIm5iZiI6MTc4NzA2NDYzNS4zNDgsInN1YiI6IjZhODQ3MTNiNmUwYjI5OGZjMDU5NWQ4NyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.qqY8hbOuCJtONtfCXNCs1FGLXP9EWpcUk6IVrqapfmY'
tmdb.USE_BEARER_AUTH = True

discover = tmdb.Discover()
response = discover.movie(page=1)

movies = response['results']

len(movies)
# Out:
# 20

# %% [markdown]
# ### Looking at the data

# %%
movies[0]
# Out:
# {'adult': False,
#  'backdrop_path': '/7iwUUcKURMT7aKfCwMy6YnGtchD.jpg',
#  'genre_ids': [878, 28, 12],
#  'id': 969681,
#  'title': 'Spider-Man: Brand New Day',
#  'original_language': 'en',
#  'original_title': 'Spider-Man: Brand New Day',
#  'overview': "Fighting crime full-time as Spider-Man in a world that doesn't remember him—and the pressure of seeing his old friends move on without him—sparks a change in Peter Parker he may not have the power to control. But that transformation might also be the only thing that can stop a shocking new threat to the city and those he loves - a powerful villain no one can even see.",
#  'popularity': 1380.7869,
#  'poster_path': '/bjiS5ipwxb9JFy3XRRN4OAilSeX.jpg',
#  'release_date': '2026-07-29',
#  'softcore': False,
#  'video': False,
#  'vote_average': 7.897,
#  'vote_count': 2136}

# %%
movie.info()
# Out:
# {'adult': False,
#  'backdrop_path': '/tlm8UkiQsitc8rSuIAscQDCnP8d.jpg',
#  'belongs_to_collection': {'id': 2344,
#   'name': 'The Matrix Collection',
#   'poster_path': '/bV9qTVHTVf0gkW0j7p7M0ILD4pG.jpg',
#   'backdrop_path': '/bRm2DEgUiYciDw3myHuYFInD7la.jpg'},
#  'budget': 63000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'}],
#  'homepage': 'http://www.warnerbros.com/matrix',
#  'id': 603,
#  'imdb_id': 'tt0133093',
#  'origin_country': ['US'],
#  'original_language': 'en',
#  'original_title': 'The Matrix',
#  'overview': 'Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth.',
#  'popularity': 42.1455,
#  'poster_path': '/dXNAPwY7VrqMAo51EKhhCJfaGb5.jpg',
#  'production_companies': [{'id': 79,
#    'logo_path': '/at4uYdwAAgNRKhZuuFX8ShKSybw.png',
#    'name': 'Village Roadshow Pictures',
# ...

# %% [markdown]
# ### Extracting movie IDs

# %%
movie_ids = [movie['id'] for movie in movies]

movie_ids
# Out:
# [969681,
#  1368337,
#  1288445,
#  1323244,
#  1084244,
#  1339713,
#  1621552,
#  634649,
#  1108427,
#  1375646,
#  1315772,
#  82023,
#  1284465,
#  1284041,
#  1083381,
#  1275779,
#  1285366,
#  1101383,
#  1273221,
#  1212763]

# %% [markdown]
# ### Getting detailed information for every movie

# %%
all_movies = []

for movie_id in movie_ids:
    movie = tmdb.Movies(movie_id)
    data = movie.info()
    all_movies.append(data)

# %%
len(all_movies)
# Out:
# 20

# %%
all_movies[0]
# Out:
# {'adult': False,
#  'backdrop_path': '/7iwUUcKURMT7aKfCwMy6YnGtchD.jpg',
#  'belongs_to_collection': {'id': 531241,
#   'name': 'Spider-Man (MCU) Collection',
#   'poster_path': '/yeba3Y820OjApZO9aJevDsNeMEd.jpg',
#   'backdrop_path': '/AvnqpRwlEaYNVL6wzC4RN94EdSd.jpg'},
#  'budget': 225000000,
#  'genres': [{'id': 878, 'name': 'Science Fiction'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'}],
#  'homepage': 'https://spidermanbrandnewday.movie',
#  'id': 969681,
#  'imdb_id': 'tt22084616',
#  'origin_country': ['US'],
#  'original_language': 'en',
#  'original_title': 'Spider-Man: Brand New Day',
# ...

# %% [markdown]
# ### Creating the DataFrame

# %%
df = pd.DataFrame(all_movies)
df.head(2)
# Out:
#    adult                     backdrop_path  \
# 0  False  /7iwUUcKURMT7aKfCwMy6YnGtchD.jpg
# 1  False  /r57L2UBLPKcHdZQYg8tagv9XqK2.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 531241, 'name': 'Spider-Man (MCU) Colle...  225000000
# 1                                               None  250000000
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                             homepage       id     imdb_id  \
# 0                 https://spidermanbrandnewday.movie   969681  tt22084616
# 1  https://www.universalpictures.com/movies/the-o...  1368337  tt33764258
#
#   origin_country original_language  ...     revenue runtime  softcore  \
# 0           [US]                en  ...  2039929225     145     False
# 1       [GB, US]                en  ...  1294477255     173     False
#
# ...

# %%
df.shape  # Data of 20 movies
# Out:
# (20, 27)

# %%
df.columns
# Out:
# Index(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres',
#        'homepage', 'id', 'imdb_id', 'origin_country', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'softcore', 'spoken_languages', 'status',
#        'tagline', 'title', 'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
nested_cols = []

for col in df.columns:
    if df[col].apply(lambda x: isinstance(x, (dict, list))).any():
        nested_cols.append(col)

nested_cols
# Out:
# ['belongs_to_collection',
#  'genres',
#  'origin_country',
#  'production_companies',
#  'production_countries',
#  'spoken_languages']

# %%
collection = pd.json_normalize(df['belongs_to_collection'])

collection = collection.rename(columns={
    'id': 'collection_id',
    'name': 'collection_name',
    'poster_path': 'collection_poster_path',
    'backdrop_path': 'collection_backdrop_path'
})

df = pd.concat(
    [df.drop(columns='belongs_to_collection'), collection],
    axis=1
)

# %%
df[['id', 'title', 'collection_id', 'collection_name']].head()
# Out:
#         id                      title  collection_id  \
# 0   969681  Spider-Man: Brand New Day       531241.0
# 1  1368337                The Odyssey            NaN
# 2   634649    Spider-Man: No Way Home       531241.0
# 3  1084244                Toy Story 5        10194.0
# 4  1323244              Rage of Stars            NaN
#
#                collection_name
# 0  Spider-Man (MCU) Collection
# 1                          NaN
# 2  Spider-Man (MCU) Collection
# 3         Toy Story Collection
# 4                          NaN

# %%
df['genres'] = df['genres'].apply(
    lambda x: ', '.join(i['name'] for i in x) if isinstance(x, list) else None
)

# origin_country
df['origin_country'] = df['origin_country'].apply(
    lambda x: ', '.join(x) if isinstance(x, list) else None
)

# production_companies
df['production_companies'] = df['production_companies'].apply(
    lambda x: ', '.join(i['name'] for i in x) if isinstance(x, list) else None
)

# production_countries
df['production_countries'] = df['production_countries'].apply(
    lambda x: ', '.join(i['name'] for i in x) if isinstance(x, list) else None
)

# spoken_languages
df['spoken_languages'] = df['spoken_languages'].apply(
    lambda x: ', '.join(i['english_name'] for i in x) if isinstance(x, list) else None
)

# %%
for col in df.columns:
    if df[col].apply(lambda x: isinstance(x, (dict, list))).any():
        print(col)

# %%
df.shape
# Out:
# (20, 30)

# %%
df.dtypes
# Out:
# adult                          bool
# backdrop_path                object
# budget                        int64
# genres                       object
# homepage                     object
# id                            int64
# imdb_id                      object
# origin_country               object
# original_language            object
# original_title               object
# overview                     object
# popularity                  float64
# poster_path                  object
# production_companies         object
# production_countries         object
# release_date                 object
# revenue                       int64
# runtime                       int64
# softcore                       bool
# spoken_languages             object
# status                       object
# tagline                      object
# title                        object
# video                          bool
# vote_average                float64
# vote_count                    int64
# ...

# %%
df.head(2)
# Out:
#    adult                     backdrop_path     budget  \
# 0  False  /7iwUUcKURMT7aKfCwMy6YnGtchD.jpg  225000000
# 1  False  /r57L2UBLPKcHdZQYg8tagv9XqK2.jpg  250000000
#
#                                genres  \
# 0  Science Fiction, Action, Adventure
# 1          Adventure, Action, Fantasy
#
#                                             homepage       id     imdb_id  \
# 0                 https://spidermanbrandnewday.movie   969681  tt22084616
# 1  https://www.universalpictures.com/movies/the-o...  1368337  tt33764258
#
#   origin_country original_language             original_title  ...    status  \
# 0             US                en  Spider-Man: Brand New Day  ...  Released
# 1         GB, US                en                The Odyssey  ...  Released
#
#                        tagline                      title  video vote_average  \
# 0  A brand new day starts now.  Spider-Man: Brand New Day  False        7.885
# ...

# %% [markdown]
# ### Checking missing values

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# collection_name             13
# collection_id               13
# collection_backdrop_path    13
# collection_poster_path      13
# adult                        0
# backdrop_path                0
# imdb_id                      0
# origin_country               0
# original_language            0
# original_title               0
# budget                       0
# genres                       0
# homepage                     0
# id                           0
# production_companies         0
# poster_path                  0
# popularity                   0
# overview                     0
# production_countries         0
# release_date                 0
# revenue                      0
# runtime                      0
# tagline                      0
# status                       0
# spoken_languages             0
# softcore                     0
# vote_count                   0
# vote_average                 0
# video                        0
# title                        0
# ...

# %%
missing_pct = (df.isna().sum() / len(df) * 100).sort_values(ascending=False)

missing_pct
# Out:
# collection_name             65.0
# collection_id               65.0
# collection_backdrop_path    65.0
# collection_poster_path      65.0
# adult                        0.0
# backdrop_path                0.0
# imdb_id                      0.0
# origin_country               0.0
# original_language            0.0
# original_title               0.0
# budget                       0.0
# genres                       0.0
# homepage                     0.0
# id                           0.0
# production_companies         0.0
# poster_path                  0.0
# popularity                   0.0
# overview                     0.0
# production_countries         0.0
# release_date                 0.0
# revenue                      0.0
# runtime                      0.0
# tagline                      0.0
# status                       0.0
# spoken_languages             0.0
# softcore                     0.0
# vote_count                   0.0
# vote_average                 0.0
# ...

# %%
df[df.isna().any(axis=1)].head()
# Out:
#    adult                     backdrop_path     budget  \
# 1  False  /r57L2UBLPKcHdZQYg8tagv9XqK2.jpg  250000000
# 4  False  /z7lZgL5tzefTfhyRtouThFhsuUS.jpg          0
# 5  False  /84FEpVVbSKYvKXDZJDZXOKBxCEm.jpg          0
# 7  False  /1RhfevWmWCVHtEqxWBEjPOC5KG1.jpg          0
# 8  False  /rZfmzpixLKLR3Hg2u0WgC7XLFl8.jpg     750000
#
#                               genres  \
# 1         Adventure, Action, Fantasy
# 4  Action, Science Fiction, Thriller
# 5    Action, Horror, Science Fiction
# 7  Horror, Science Fiction, Thriller
# 8                   Horror, Thriller
#
#                                             homepage       id     imdb_id  \
# 1  https://www.universalpictures.com/movies/the-o...  1368337  tt33764258
# 4                                                     1323244  tt29512655
# 5                 https://wellgousa.com/films/colony  1375646  tt34385135
# 7             https://www.netflix.com/title/81914143  1284041  tt32268156
# ...

# %% [markdown]
# ### Focusing only on that columns which have missing values

# %%
missing = df.isna().sum()

missing[missing > 0].sort_values(ascending=False)
# Out:
# collection_id               13
# collection_name             13
# collection_poster_path      13
# collection_backdrop_path    13
# dtype: int64

# %% [markdown]
# ### Understanding why belongs_to_collection has missing values

# %% [raw]
# For movies that don't belong to a collection, TMDB returns: None
#
# It means: This movie doesn't belong to a collection.
#
# Therefore, we should not automatically replace it with the mean, median, or mode.

# %%
df['collection_name'] = df['collection_name'].fillna('No Collection')
df['collection_name']
# Out:
# 0         Spider-Man (MCU) Collection
# 1                       No Collection
# 2         Spider-Man (MCU) Collection
# 3                Toy Story Collection
# 4                       No Collection
# 5                       No Collection
# 6                  Minions Collection
# 7                       No Collection
# 8                       No Collection
# 9                       No Collection
# 10                      No Collection
# 11                      No Collection
# 12                      No Collection
# 13    Evil Dead Standalone Collection
# 14                      No Collection
# 15                      No Collection
# 16                      No Collection
# 17                      No Collection
# 18            The Avengers Collection
# 19        Spider-Man (MCU) Collection
# Name: collection_name, dtype: object

# %%
df['release_date'].dtype
# Out:
# dtype('O')

# %%
df[['budget', 'revenue', 'runtime', 'popularity', 'vote_average', 'vote_count']].dtypes
# Out:
# budget            int64
# revenue           int64
# runtime           int64
# popularity      float64
# vote_average    float64
# vote_count        int64
# dtype: object

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
df['release_date'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ### Check for duplicate movies

# %%
df['id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['id'].nunique()
# Out:
# 20

# %%
len(df)
# Out:
# 20

# %%
import requests
import pandas as pd

# %%
base_url = "https://api.themoviedb.org"

# %%
end_point = "/3/movie/popular"

# %%
final_url = base_url + end_point
final_url
# Out:
# 'https://api.themoviedb.org/3/movie/popular'

# %%
access_token = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2YTdkM2IwZjUyZjAxMWFjNTUwNWRjYTUyOTVmZjIyYSIsIm5iZiI6MTc4NzA2NDYwNi45Njk5OTk4LCJzdWIiOiI2YTg0NzExZTE3M2FjN2JlNjE1OTU5YTgiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.TByo6oaVIW8ZKKELWM87Ql8p_yQquok3wHbsCm0MyCI"

# %%
headers = {
    "Authorization": f"Bearer {access_token}",
    "accept": "application/json"
}

# %%
all_movies = []

for page in range(1,31):
    response = requests.get(final_url, headers=headers, params = {"page":page})

    if response.status_code == 200:
        data = response.json()
        all_movies.extend(data["results"])
    else:
        print(f"Error on page {page}: {response.status_code}")

df = pd.DataFrame(all_movies)

# %%
df.shape
# Out:
# (600, 15)

# %% [raw]
#  What characteristics are associated with successful movies, and how has the movie industry changed over time?
# The analysis should help answer questions around:
#
# Which genres perform best?
# Are highly rated movies actually popular?
# Does a bigger audience lead to higher ratings?
# Which years produced the strongest movies?
# Has movie production increased over time?
# Which genres dominate the industry?
# Does movie popularity depend on ratings?
# Are highly voted movies more reliable than movies with very few votes?
# Which movies should a streaming platform consider for acquisition or promotion?
#
# TMDB provides endpoints for popular movies, top-rated movies, and a powerful /discover/movie endpoint with many filtering and sorting options.
# Analyze TMDB movie data to identify:
#
# Movie industry trends
# High-performing genres
# Relationship between ratings and popularity
# Relationship between ratings and vote counts
# Most successful release periods
# Characteristics of highly successful movies
# Movies with strong audience engagement
# Potential recommendations for a streaming/movie company

# %%
df.head(2)
# Out:
#    adult                     backdrop_path      genre_ids       id  \
# 0  False  /7iwUUcKURMT7aKfCwMy6YnGtchD.jpg  [878, 28, 12]   969681
# 1  False   /RMXG8myu1aGlNUsRjtxzmpdMK0.jpg   [12, 28, 14]  1368337
#
#                        title original_language             original_title  \
# 0  Spider-Man: Brand New Day                en  Spider-Man: Brand New Day
# 1                The Odyssey                en                The Odyssey
#
#                                             overview  popularity  \
# 0  Fighting crime full-time as Spider-Man in a wo...   1257.7257
# 1  Odysseus, the legendary King of Ithaca, embark...    609.3017
#
#                         poster_path release_date  softcore  video  \
# 0  /bjiS5ipwxb9JFy3XRRN4OAilSeX.jpg   2026-07-29     False  False
# 1  /5rhTDKUhPYvpdQIijFIs5VoWsON.jpg   2026-07-15     False  False
#
#    vote_average  vote_count
# 0         7.887        2198
# 1         7.988        3226

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              600 non-null    bool
#  1   backdrop_path      591 non-null    object
#  2   genre_ids          600 non-null    object
#  3   id                 600 non-null    int64
#  4   title              600 non-null    object
#  5   original_language  600 non-null    object
#  6   original_title     600 non-null    object
#  7   overview           600 non-null    object
#  8   popularity         600 non-null    float64
#  9   poster_path        600 non-null    object
#  10  release_date       600 non-null    object
#  11  softcore           600 non-null    bool
#  12  video              600 non-null    bool
#  13  vote_average       600 non-null    float64
#  14  vote_count         600 non-null    int64
# dtypes: bool(3), float64(2), int64(2), object(8)
# ...

# %%
df.columns
# Out:
# Index(['adult', 'backdrop_path', 'genre_ids', 'id', 'title',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'poster_path', 'release_date', 'softcore', 'video', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')

# %%
df['id'].duplicated().sum()
# Out:
# np.int64(9)

# %%
df = df.drop_duplicates(subset='id')

# %%
df['id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df['release_year'] = df['release_date'].dt.year

df[['title', 'release_year', 'popularity', 'vote_average', 'vote_count']].head()
# Out:
#                        title  release_year  popularity  vote_average  \
# 0  Spider-Man: Brand New Day        2026.0   1257.7257         7.887
# 1                The Odyssey        2026.0    609.3017         7.988
# 2                     Mutiny        2026.0    507.5238         6.500
# 3              Rage of Stars        2026.0    292.9905         5.565
# 4            Facing El Chapo        2026.0    327.4675         8.749
#
#    vote_count
# 0        2198
# 1        3226
# 2         181
# 3          46
# 4         213

# %%
df.isnull().sum()
# Out:
# adult                0
# backdrop_path        9
# genre_ids            0
# id                   0
# title                0
# original_language    0
# original_title       0
# overview             0
# popularity           0
# poster_path          0
# release_date         1
# softcore             0
# video                0
# vote_average         0
# vote_count           0
# release_year         1
# dtype: int64

# %%
df[['popularity', 'vote_average', 'vote_count']].describe()
# Out:
#         popularity  vote_average    vote_count
# count   591.000000    591.000000    591.000000
# mean     40.944824      7.028264   8295.401015
# std      67.558086      1.338826   8600.468470
# min      16.203000      0.000000      0.000000
# 25%      21.387800      6.643500    634.500000
# 50%      26.007500      7.294000   5311.000000
# 75%      37.224600      7.822500  13718.000000
# max    1257.725700      9.300000  40913.000000

# %%
df['release_year'].dtype
# Out:
# dtype('float64')

# %%
df=pd.read_csv('popular_movies.csv')

# %%
df.head(2)
# Out:
#    Unnamed: 0  adult                     backdrop_path      genre_ids  \
# 0           0  False  /7iwUUcKURMT7aKfCwMy6YnGtchD.jpg  [878, 28, 12]
# 1           1  False   /RMXG8myu1aGlNUsRjtxzmpdMK0.jpg   [12, 28, 14]
#
#         id                      title original_language  \
# 0   969681  Spider-Man: Brand New Day                en
# 1  1368337                The Odyssey                en
#
#               original_title  \
# 0  Spider-Man: Brand New Day
# 1                The Odyssey
#
#                                             overview  popularity  \
# 0  Fighting crime full-time as Spider-Man in a wo...   1346.7581
# 1  Odysseus, the legendary King of Ithaca, embark...    620.9085
#
#                         poster_path release_date  softcore  video  \
# 0  /bjiS5ipwxb9JFy3XRRN4OAilSeX.jpg   2026-07-29     False  False
# 1  /5rhTDKUhPYvpdQIijFIs5VoWsON.jpg   2026-07-15     False  False
#
#    vote_average  vote_count
# 0         7.893        2163
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'adult', 'backdrop_path', 'genre_ids', 'id', 'title',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'poster_path', 'release_date', 'softcore', 'video', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df.columns
# Out:
# Index(['adult', 'backdrop_path', 'genre_ids', 'id', 'title',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'poster_path', 'release_date', 'softcore', 'video', 'vote_average',
#        'vote_count'],
#       dtype='object')
